# %%
import numpy
import pandas 
import matplotlib.pyplot as plt

# %%
print("Assignment 2")
list1 = [1, 2, 5]
list2 = [2, 4, 6]
xy = []
for num1, num2 in zip(list1, list2):
   xy.append(num1*num2)
print(xy)
# Out:
# Assignment 2
# [2, 8, 30]

# %%
print("Assignment 3")
def xySum_Prod(list1,list2):
    result=0
    for num1, num2 in zip(list1, list2):
       ##result = result + (num1*num2)
       result += (num1*num2)
    return result

print(xySum_Prod(list1, list2));
# Out:
# Assignment 3
# 40

# %%
print("Assignment 4")
def find_a(x,y):
    n = len(x)
    xSum = sum(x)
    ySum = sum(y)
    xySum = xySum_Prod(x,y)
    x2Sum = xySum_Prod(x,x)
    a = ((ySum * x2Sum) - (xSum*xySum))/(n*x2Sum - xSum*xSum)
    return a
a = find_a(x,y)
print(f"a: {a}")
# Out:
# Assignment 4
# a: 42.522482771822375

# %%
#Cost per click of individual keywords
x = [1.0, 2.1, 2.3, 2.5, 4.1, 4.5, 4.9, 5.9, 8.9]
#Total amount of clicks per day
y = [48.2, 63.0, 89.0, 71.0, 89.0, 82.2, 70.0, 80.0, 150.0]

# %%
print("Assignment 5")
def find_b(x,y):
    n = len(x)
    xSum = sum(x)
    ySum = sum(y)
    xySum = xySum_Prod(x,y)
    x2Sum = xySum_Prod(x,x)
    b = (n*xySum - xSum*ySum)/(n*x2Sum - xSum**2)
    return b
b = find_b(x,y)
print(f"b: {b}")
# Out:
# Assignment 5
# b: 9.936399310872888

# %%
#b = 9.8 # try later 8 9 9.8
#a = 44.5 # try later 50 40 44.5

def h(x):
 return b*x + a

h(2)
# Out:
# 62.395281393568155

# %%
A, B, C = 2.7, 1.6, 40.0
print(A,B,C)
def hPolynomial(x):
    return A*x**2 + B*x + C

hPolynomial(2)
# Out:
# 2.7 1.6 40.0
# 54.0

# %%
plt.axis([0, 10, 0, 200])
plt.scatter(x, y)

regression_line = [h(item)for item in [0, 10]]
polynomial_line = [hPolynomial(item)for item in [0, 10]]

plt.xlabel("individual keywords")
plt.ylabel("amount of clicks per day")
plt.title("Linear Regression")
plt.plot([0, 10], regression_line)
plt.plot([0, 10], polynomial_line)

# %%
def Sum_Of_Squares(x_list, y_list, hFunc):
    xy2 =[]
    for numX, numY in zip(x_list,y_list):
        dif = hFunc(numX) - numY
        xy2.append(dif**2)
    return xy2

result = Sum_Of_Squares(x, y, h)
print(result)
# Out:
# [18.138076594302703, 0.15125979677174367, 558.0838703651315, 13.224270080948752, 32.92785797352968, 25.364112922013504, 449.89970784470603, 447.2057048873784, 362.65730549999654]

# %%
from sklearn.metrics import mean_squared_error
import math
def RMSE(x_list, y_list, hFunc): 
    dif = []
    for numX, numY in zip(x_list,y_list):
        dif.append(hFunc(numX))
    MSE = mean_squared_error(y_list,dif)
    RMSE = math.sqrt(MSE)
    print(dif)
    return RMSE

print(RMSE(x,y,h))
print(RMSE(x,y,hPolynomial))
# Out:
# [52.45888208269526, 63.38892132465544, 65.37620118683002, 67.36348104900459, 83.26171994640121, 87.23627967075038, 91.21083939509953, 101.14723870597243, 130.95643663859107]
# 14.558892532533658
# [44.3, 55.267, 57.963, 60.875, 91.947, 101.875, 112.66700000000002, 143.42700000000002, 268.1070000000001]
# 48.68188276282395
